# %% [markdown]
# # CS6405 - Data Mining - Second Assignment
#
# ### Objective
#
# The Boolean satisfiability (SAT) problem consists in determining whether a Boolean formula is satisfiable or not. This problem is one of the most widely studied combinatorial problems in computer science. It is the classic NP-complete problem. Over the past number of decades, a significant amount of research work has focused on solving SAT problems with both complete and incomplete solvers.
#
# An extended version of the problem is Model Counting (#SAT). In #SAT the solver needs to compute the number of solutions of a Boolean formula. A wide variety of solvers have been designed to tackle this problem.
#
# In this project, we want to create an Algorithm Selection (AS) approach to Model Counting. For each #SAT instance, there is a specific solver that works better than the others, the goal of your machine learing approach is to classify it.
#
# In AS we represent #SAT problems with a vector of 72 features with general information about the problem, e.g., number of variables, number of clauses, etc. There is no need to understand the features to be able to complete the assignment. For each instance, there is a 'label' column representing the name of the optimal solver.

# %% [markdown]
# ## Data Preparation

# %%
import pandas as pd

df = pd.read_csv("train_data.csv")
df
# Out:
#            c       v  clauses_vars_ratio  vars_clauses_ratio  vcg_var_mean  \
# 0      681.0   238.0            2.861345            0.349486      0.011143
# 1      368.0   140.0            2.628571            0.380435      0.018012
# 2     1935.0  1920.0            1.007812            0.992248      0.001760
# 3     3452.0  2821.0            1.223680            0.817207      0.000968
# 4      694.0   294.0            2.360544            0.423631      0.007656
# ...      ...     ...                 ...                 ...           ...
# 1331   949.0   351.0            2.703704            0.369863      0.006701
# 1332  1450.0   608.0            2.384868            0.419310      0.004427
# 1333   250.0   100.0            2.500000            0.400000      0.026000
# 1334  4949.0  3422.0            1.446230            0.691453      0.000764
# 1335   280.0   120.0            2.333333            0.428571      0.018442
#
#       vcg_var_coeff  vcg_var_min  vcg_var_max  vcg_var_entropy  \
# 0          0.905300     0.005874     0.111601         1.880038
# 1          0.510753     0.005435     0.054348         1.851609
# 2          1.723720     0.000000     0.012403         1.280404
# 3          1.436774     0.000290     0.006083         1.192878
# 4          0.493513     0.002882     0.040346         1.776102
# ...             ...          ...          ...              ...
# 1331       1.151888     0.002012     0.063380         1.857919
# 1332       1.552830     0.002408     0.161349         1.659495
# 1333       0.555766     0.000000     0.096000         1.751533
# 1334       0.770643     0.000202     0.004445         1.835041
# 1335       0.490373     0.000000     0.045198         1.773180
#
#       vcg_clause_mean  ...  gsat_FirstLocalMinStep_CoeffVariance  \
# 0            0.011143  ...                              0.210148
# 1            0.018012  ...                              0.124438
# 2            0.001760  ...                              0.066708
# 3            0.000968  ...                              0.053628
# 4            0.007656  ...                              0.086841
# ...               ...  ...                                   ...
# 1331         0.006701  ...                              0.079108
# 1332         0.004427  ...                              0.062664
# 1333         0.026000  ...                              0.140708
# 1334         0.000764  ...                              0.032571
# 1335         0.018442  ...                              0.120101
#
#       gsat_FirstLocalMinStep_Median  gsat_FirstLocalMinStep_Q.10  \
# 0                              50.0                         42.0
# 1                              34.0                         29.0
# 2                             102.0                         94.0
# 3                             192.0                        179.0
# 4                              72.0                         64.0
# ...                             ...                          ...
# 1331                           81.0                         73.0
# 1332                          136.0                        125.0
# 1333                           26.0                         21.0
# 1334                          461.0                        441.0
# 1335                           35.0                         30.0
#
#       gsat_FirstLocalMinStep_Q.90  gsat_BestAvgImprovement_Mean  \
# 0                            57.0                      0.954568
# 1                            40.0                      1.693036
# 2                           111.0                      0.398129
# 3                           205.0                      0.247528
# 4                            80.0                      0.822829
# ...                           ...                           ...
# 1331                         89.0                      0.781888
# 1332                        147.0                      0.776364
# 1333                         30.0                      2.093007
# 1334                        479.0                      0.202805
# 1335                         41.0                      1.982299
#
#       gsat_BestAvgImprovement_CoeffVariance  gsat_FirstLocalMinRatio_Mean  \
# 0                                  0.591296                      1.141656
# 1                                  0.244951                      0.969015
# 2                                  0.824694                      0.935730
# 3                                  0.702251                      0.923327
# 4                                  0.209989                      0.855568
# ...                                     ...                           ...
# 1331                               0.256505                      0.837929
# 1332                               0.174557                      0.855907
# 1333                               0.117640                      1.000000
# 1334                               0.220101                      0.856952
# 1335                               0.141661                      0.995087
#
#       gsat_FirstLocalMinRatio_CoeffVariance  gsat_EstACL_Mean     label
# 0                                  3.197217      9.240515e+09      gpmc
# 1                                  0.029930      5.401642e+03        d4
# 2                                  0.092714      3.561823e+04      gpmc
# 3                                  0.026977      1.268929e+05      gpmc
# 4                                  0.045802      1.647598e+04        d4
# ...                                     ...               ...       ...
# 1331                               0.066291      1.643030e+04  sharpsat
# 1332                               0.031698      3.816192e+04      gpmc
# 1333                               0.000000      3.168220e+03      gpmc
# 1334                               0.016884      6.236767e+05      gpmc
# 1335                               0.008575      6.045684e+03      gpmc
#
# [1336 rows x 73 columns]

# %%
# Label or target variable
df['label'].value_counts()
# Out:
# label
# gpmc        921
# d4          168
# ganak       140
# addmc        55
# sharpsat     52
# Name: count, dtype: int64

# %% [markdown]
# # Tasks
#
# ## Basic models and evaluation
#
# Using Scikit-learn, train and evaluate a k-NN classifier using 70% of the dataset from training and 30% for testing. For this part of the project, we are not interested in optimising the parameters; we just want to get an idea of the dataset.

# %%
# YOUR CODE HERE
from sklearn import model_selection
from sklearn import neighbors

labels = df['label']
features = df.drop('label', axis = 1)

train_features, test_features, train_labels, test_labels = model_selection.train_test_split(features, labels, test_size=0.3, random_state= 6405)

knn = neighbors.KNeighborsClassifier()

knn.fit(train_features,train_labels)
print("KNN Train accuracy for default value of k = 5 :", end=" ")
print(knn.score(train_features, train_labels)*100, end="")
print("%")
print("KNN Testing accuracy for default value of k = 5 :", end=" ")
print(knn.score(test_features, test_labels)*100, end="")
print("%")
# Out:
# KNN Train accuracy for default value of k = 5 : 79.25133689839572%
# KNN Testing accuracy for default value of k = 5 : 68.3291770573566%

# %% [markdown]
# ## Robust evaluation
#
# In this section, we are interested in more rigorous techniques by implementing more sophisticated methods. Do your best to improve the k-NN classifier performances on this dataset.
#
# For instance, you could consider:
# * Hold-out and cross-validation.
# * Hyper-parameter tuning.
# * Feature selection.
# * Feature normalisation.
# * Etc.
#
#
#
# Your report should provide concrete information about your reasoning, everything should be well-explained.
#
# The key to geting good marks is to show that you evaluated different methods and that you correctly selected the configuration.

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectPercentile, f_classif
import warnings
warnings.filterwarnings('ignore')

# %%
for x in [StandardScaler(), MinMaxScaler()]:
  scaler = x
  train_features_Scaled = scaler.fit_transform(train_features)
  pca = PCA(2)
  fit = pca.fit(train_features)
  # summarize components
  print("Explained Variance: %s" % fit.explained_variance_ratio_)
# Out:
# Explained Variance: [0.94593909 0.05406091]
# Explained Variance: [0.94593909 0.05406091]

# %%
knn_param_grid = {
    'KNN__n_neighbors': [2,3,5,7,9,11,13,15,20,25],
    'PCA__n_components': [2,3,4,5]
}
for x in [StandardScaler(), MinMaxScaler()]:
  pipeline_knn = Pipeline([('scaler', x), \
                           ('PCA', PCA()), \
                           ('KNN', neighbors.KNeighborsClassifier())])

  knn_best = GridSearchCV(pipeline_knn, knn_param_grid, scoring="accuracy")

  # Run the GridSearchCV
  knn_best.fit(train_features, train_labels)
  print("best params for", x, ":")
  # Print the best parameters and the score
  print(knn_best.best_params_)
  print("Corresponding Train accuracy:", (knn_best.best_score_ * 100), "%")

  # print the testing data accuracy
  print("Corresponding Test accuracy:", (knn_best.best_estimator_.score(test_features, test_labels) * 100), "%")
  print("-"* 100)
# Out:
# best params for StandardScaler() :
# {'KNN__n_neighbors': 5, 'PCA__n_components': 5}
# Corresponding Train accuracy: 73.26203208556149 %
# Corresponding Test accuracy: 69.82543640897757 %
# ----------------------------------------------------------------------------------------------------
# best params for MinMaxScaler() :
# {'KNN__n_neighbors': 7, 'PCA__n_components': 5}
# Corresponding Train accuracy: 73.36898395721924 %
# Corresponding Test accuracy: 68.07980049875312 %
# ----------------------------------------------------------------------------------------------------

# %%
knn_param_grid = {
    'KNN__n_neighbors': [5,7,9,11,13,15,20,25],
    'PCA__n_components': [2,3,4,5,6,7],
    'SelectPercentile__percentile': [20, 30, 40, 50, 60, 70]
}
for x in [StandardScaler(), MinMaxScaler()]:

    steps_knn = [('scaler', x)]
    steps_knn.append(('SelectPercentile', SelectPercentile(score_func = f_classif)))
    steps_knn.append(('PCA', PCA()))
    steps_knn.append(('KNN', neighbors.KNeighborsClassifier()))

    pipeline_knn = Pipeline(steps_knn)

    knn_best = GridSearchCV(pipeline_knn, knn_param_grid, scoring="accuracy")

    # Run the GridSearchCV
    knn_best.fit(train_features, train_labels)
    print("best params for", x, ":")
    # Print the best parameters and the score
    print(knn_best.best_params_)
    print("Corresponding Train accuracy:", (knn_best.best_score_ * 100), "%")

    # print the testing data accuracy
    print("Corresponding Test accuracy:", (knn_best.best_estimator_.score(test_features, test_labels) * 100), "%")
    print("-"* 100)
# Out:
# best params for StandardScaler() :
# {'KNN__n_neighbors': 9, 'PCA__n_components': 4, 'SelectPercentile__percentile': 20}
# Corresponding Train accuracy: 74.43850267379679 %
# Corresponding Test accuracy: 70.57356608478803 %
# ----------------------------------------------------------------------------------------------------
# best params for MinMaxScaler() :
# {'KNN__n_neighbors': 11, 'PCA__n_components': 6, 'SelectPercentile__percentile': 20}
# Corresponding Train accuracy: 74.33155080213905 %
# Corresponding Test accuracy: 71.3216957605985 %
# ----------------------------------------------------------------------------------------------------

# %%
# FINAL MODEL FOR TASK 2

knn_param_grid = {
    'KNN__n_neighbors': [5,7,9,11,13,15,20,25],
    #'PCA__n_components': [2,3,4],
    'SelectPercentile__percentile': [20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
}
for x in [StandardScaler(), MinMaxScaler()]:


    steps_knn = [('scaler', x)]
    steps_knn.append(('SelectPercentile', SelectPercentile(score_func = f_classif)))
    #steps_knn.append(('PCA', PCA()))
    steps_knn.append(('KNN', neighbors.KNeighborsClassifier()))

    pipeline_knn = Pipeline(steps_knn)

    knn_best = GridSearchCV(pipeline_knn, knn_param_grid, scoring="accuracy")

    # Run the GridSearchCV
    knn_best.fit(train_features, train_labels)
    print("best params for", x, ":")
    # Print the best parameters and the score
    print(knn_best.best_params_)
    print("Corresponding Train accuracy:", (knn_best.best_score_ * 100), "%")

    # print the testing data accuracy
    print("Corresponding Test accuracy:", (knn_best.best_estimator_.score(test_features, test_labels) * 100), "%")
    print("Number of columns chosen by SelectPercentile: ", sum(knn_best.best_estimator_.named_steps['SelectPercentile'].get_support()))
    print("-"* 100)
# Out:
# best params for StandardScaler() :
# {'KNN__n_neighbors': 9, 'SelectPercentile__percentile': 20}
# Corresponding Train accuracy: 74.33155080213902 %
# Corresponding Test accuracy: 72.81795511221945 %
# Number of columns chosen by SelectPercentile:  15
# ----------------------------------------------------------------------------------------------------
# best params for MinMaxScaler() :
# {'KNN__n_neighbors': 11, 'SelectPercentile__percentile': 20}
# Corresponding Train accuracy: 74.01069518716577 %
# Corresponding Test accuracy: 73.81546134663341 %
# Number of columns chosen by SelectPercentile:  15
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Task 2 - Explanation
#
# #### GridSearchCV was performed on a pipeline wherein Scaling (either MinMaxScaler or StandardScaler) along with Feature Selection (SelectPercentile) and Dimensional Reduction technique (PCA) was used either separately or in tandem prior to the K-Nearest Neighbours model. So, the pipeline had either 3 or 4 components in it, and hyperparameterisation was performed for all components except scaling, as only the type of scaling was switched across pipelines. The overall pipeline was fit and evaluated on 5-fold Cross Validation.
# #### 1) Pipeline with different scalers switched but with only PCA applied yielded a maximum of 69.8% validation accuracy. (Best one - MinMaxScaler, 4 components of PCA and 7 neighbours in KNN)
# #### 2) Next, pipeline was fit with both PCA and SelectPercentile where SelectPercentile performed ANOVA test between each input column with the output column to select the columns in the top 20 percentile of scores. Here the validation accuracy improved but was limited to 71.32%.
# #### 3) Finally, the best results were obtained when the cross validation was performed on pipeline with MinMaxScaling, SelectPercentile and KNN model (No PCA in this model) with parameters KNN Neighbours - 11 and 20% of the top features were chosen by SelectPercentile (15 features) method. Final and best validation accuracy achieved with this method - 73.81%

# %% [markdown]
# ## New classifier
#
# Replicate the previous task for a classifier different than K-NN and decision trees. Briefly describe your choice.
# Try to create the best model for the given dataset.

# %%
# YOUR CODE HERE

## GRIDSEARCH FOR MULTIPLE MODELS
# !pip install catboost
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.feature_selection import SelectPercentile, f_classif
from sklearn.ensemble import GradientBoostingClassifier, VotingClassifier, RandomForestClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
import time

# Defining parameter grids for each classifier
gbm_param_grid = {
    'SelectPercentile__percentile': [25, 30, 35, 40],
    'GBM__n_estimators': [50, 100],
    'GBM__learning_rate': [0.05, 0.1, 0.5],
    'GBM__min_samples_leaf': [5, 10, 15, 20]
}

lgbm_param_grid = {
    'SelectPercentile__percentile': [25, 30, 35, 40],
    'LGBM__n_estimators': [15, 25, 40],
    'LGBM__learning_rate': [0.05, 0.1, 0.5],
    'LGBM__min_child_samples': [5, 10, 15]
}

rf_param_grid = {
    'SelectPercentile__percentile': [25, 30, 35, 40],
    'RF__n_estimators': [15, 25, 40],
    'RF__min_samples_leaf': [5, 10, 15]
}

xgb_param_grid = {
    'SelectPercentile__percentile': [25, 30, 35, 40],
    'XGB__n_estimators': [15, 25, 40],
    'XGB__learning_rate': [0.05, 0.1, 0.5],
    'XGB__min_child_weight' : [5, 10, 15]
}

catboost_param_grid = {
    'SelectPercentile__percentile': [25, 30, 35, 40],
    'CatBoost__iterations': [15, 25, 40],
    'CatBoost__learning_rate': [0.05, 0.1, 0.5],
    'CatBoost__min_child_samples' : [5, 10 ,15]
}

ensemble_param_grid = {
    'SelectPercentile__percentile': [25, 30, 35, 40],
    'voting__weights': [[1,1,1],[1,2,1],[1,1,2],[2,1,1]]
}

encoder = LabelEncoder()
train_labels_numeric = encoder.fit_transform(train_labels)

for scaler in [MinMaxScaler()]:

    steps = [('scaler', scaler)]
    steps.append(('SelectPercentile', SelectPercentile(score_func=f_classif)))

    # RandomForest
    steps_rf = steps + [('RF', RandomForestClassifier())]
    pipeline_rf = Pipeline(steps_rf)
    grid_search_rf = GridSearchCV(pipeline_rf, param_grid = rf_param_grid, scoring = 'accuracy')
    grid_search_rf.fit(train_features, train_labels)

    # GBM
    steps_gbm = steps + [('GBM', GradientBoostingClassifier())]
    pipeline_gbm = Pipeline(steps_gbm)
    grid_search_gbm = GridSearchCV(pipeline_gbm, param_grid = gbm_param_grid, scoring='accuracy')
    grid_search_gbm.fit(train_features, train_labels)

    # LightGBM
    steps_lgbm = steps + [('LGBM', LGBMClassifier())]
    pipeline_lgbm = Pipeline(steps_lgbm)
    grid_search_lgbm = GridSearchCV(pipeline_lgbm, param_grid = lgbm_param_grid, scoring='accuracy')
    grid_search_lgbm.fit(train_features, train_labels)

    # XGBoost
    steps_xgb = steps + [('XGB', XGBClassifier())]
    pipeline_xgb = Pipeline(steps_xgb)
    grid_search_xgb = GridSearchCV(pipeline_xgb, param_grid = xgb_param_grid, scoring='accuracy')
    grid_search_xgb.fit(train_features, train_labels_numeric)

    # CatBoost
    steps_catboost = steps + [('CatBoost', CatBoostClassifier())]
    pipeline_catboost = Pipeline(steps_catboost)
    grid_search_catboost = GridSearchCV(pipeline_catboost, param_grid = catboost_param_grid, scoring='accuracy')
    grid_search_catboost.fit(train_features, train_labels)

    # Ensemble models (VotingClassifier)
    ensemble_clf = steps + [('voting', VotingClassifier(estimators=[('GBM', grid_search_gbm.best_estimator_), ('LGBM', grid_search_lgbm.best_estimator_),  ('RF', grid_search_rf.best_estimator_)], voting='hard'))]
    pipeline_ensemble = Pipeline(ensemble_clf)
    grid_search_ensemble = GridSearchCV(pipeline_ensemble, param_grid = ensemble_param_grid, scoring='accuracy')
    grid_search_ensemble.fit(train_features, train_labels)
# Out:
# Streaming output truncated to the last 5000 lines.
# 18:	learn: 0.7235716	total: 533ms	remaining: 589ms
# 19:	learn: 0.7072334	total: 568ms	remaining: 568ms
# 20:	learn: 0.6990066	total: 594ms	remaining: 537ms
# 21:	learn: 0.6880641	total: 620ms	remaining: 508ms
# 22:	learn: 0.6771390	total: 647ms	remaining: 478ms
# 23:	learn: 0.6679460	total: 680ms	remaining: 453ms
# 24:	learn: 0.6600950	total: 715ms	remaining: 429ms
# 25:	learn: 0.6552189	total: 723ms	remaining: 389ms
# 26:	learn: 0.6476886	total: 749ms	remaining: 361ms
# 27:	learn: 0.6398618	total: 781ms	remaining: 335ms
# 28:	learn: 0.6326457	total: 808ms	remaining: 307ms
# 29:	learn: 0.6254603	total: 836ms	remaining: 279ms
# 30:	learn: 0.6161183	total: 863ms	remaining: 251ms
# 31:	learn: 0.6083289	total: 890ms	remaining: 222ms
# 32:	learn: 0.5998832	total: 918ms	remaining: 195ms
# 33:	learn: 0.5941276	total: 944ms	remaining: 167ms
# 34:	learn: 0.5897500	total: 970ms	remaining: 139ms
# 35:	learn: 0.5851127	total: 1s	remaining: 111ms
# 36:	learn: 0.5789794	total: 1.03s	remaining: 83.6ms
# 37:	learn: 0.5735211	total: 1.06s	remaining: 55.8ms
# 38:	learn: 0.5678492	total: 1.09s	remaining: 27.9ms
# 39:	learn: 0.5625608	total: 1.11s	remaining: 0us
# 0:	learn: 1.4502918	total: 38.7ms	remaining: 1.51s
# 1:	learn: 1.3312673	total: 75.6ms	remaining: 1.44s
# 2:	learn: 1.2455542	total: 105ms	remaining: 1.3s
# 3:	learn: 1.1740394	total: 131ms	remaining: 1.18s
# 4:	learn: 1.1097423	total: 157ms	remaining: 1.1s
# 5:	learn: 1.0569075	total: 185ms	remaining: 1.05s
# 6:	learn: 1.0217224	total: 188ms	remaining: 887ms
# 7:	learn: 0.9792306	total: 215ms	remaining: 861ms
# 8:	learn: 0.9389170	total: 242ms	remaining: 835ms
# 9:	learn: 0.9070253	total: 271ms	remaining: 814ms
# 10:	learn: 0.8800652	total: 310ms	remaining: 818ms
# 11:	learn: 0.8526124	total: 337ms	remaining: 787ms
# 12:	learn: 0.8293253	total: 364ms	remaining: 756ms
# 13:	learn: 0.8121369	total: 393ms	remaining: 730ms
# 14:	learn: 0.7953003	total: 421ms	remaining: 701ms
# 15:	learn: 0.7750677	total: 449ms	remaining: 673ms
# 16:	learn: 0.7595554	total: 475ms	remaining: 642ms
# 17:	learn: 0.7434608	total: 501ms	remaining: 612ms
# 18:	learn: 0.7306829	total: 536ms	remaining: 592ms
# 19:	learn: 0.7178348	total: 576ms	remaining: 576ms
# 20:	learn: 0.7082704	total: 604ms	remaining: 546ms
# 21:	learn: 0.7012093	total: 630ms	remaining: 515ms
# 22:	learn: 0.6904382	total: 656ms	remaining: 485ms
# 23:	learn: 0.6799518	total: 681ms	remaining: 454ms
# 24:	learn: 0.6684286	total: 708ms	remaining: 425ms
# 25:	learn: 0.6606309	total: 734ms	remaining: 395ms
# 26:	learn: 0.6517975	total: 772ms	remaining: 372ms
# 27:	learn: 0.6449425	total: 802ms	remaining: 344ms
# 28:	learn: 0.6372276	total: 830ms	remaining: 315ms
# 29:	learn: 0.6303585	total: 856ms	remaining: 285ms
# 30:	learn: 0.6244374	total: 882ms	remaining: 256ms
# 31:	learn: 0.6151840	total: 909ms	remaining: 227ms
# 32:	learn: 0.6095603	total: 935ms	remaining: 198ms
# 33:	learn: 0.6036453	total: 962ms	remaining: 170ms
# 34:	learn: 0.5983656	total: 996ms	remaining: 142ms
# 35:	learn: 0.5916497	total: 1.02s	remaining: 114ms
# 36:	learn: 0.5874107	total: 1.05s	remaining: 85ms
# 37:	learn: 0.5820731	total: 1.07s	remaining: 56.6ms
# 38:	learn: 0.5778636	total: 1.1s	remaining: 28.2ms
# 39:	learn: 0.5730369	total: 1.14s	remaining: 0us
# 0:	learn: 1.4589894	total: 47ms	remaining: 1.83s
# 1:	learn: 1.3354998	total: 76.1ms	remaining: 1.45s
# 2:	learn: 1.2328212	total: 103ms	remaining: 1.27s
# 3:	learn: 1.1517063	total: 130ms	remaining: 1.17s
# 4:	learn: 1.0875465	total: 158ms	remaining: 1.11s
# 5:	learn: 1.0341911	total: 185ms	remaining: 1.05s
# 6:	learn: 0.9906258	total: 214ms	remaining: 1.01s
# 7:	learn: 0.9522913	total: 241ms	remaining: 966ms
# 8:	learn: 0.9187128	total: 279ms	remaining: 961ms
# 9:	learn: 0.8862104	total: 306ms	remaining: 919ms
# 10:	learn: 0.8569765	total: 336ms	remaining: 886ms
# 11:	learn: 0.8308657	total: 363ms	remaining: 847ms
# 12:	learn: 0.8100861	total: 398ms	remaining: 826ms
# 13:	learn: 0.7909402	total: 429ms	remaining: 797ms
# 14:	learn: 0.7700563	total: 456ms	remaining: 759ms
# 15:	learn: 0.7545477	total: 488ms	remaining: 733ms
# 16:	learn: 0.7389414	total: 519ms	remaining: 702ms
# 17:	learn: 0.7242454	total: 545ms	remaining: 666ms
# 18:	learn: 0.7106325	total: 573ms	remaining: 634ms
# 19:	learn: 0.6979928	total: 600ms	remaining: 600ms
# 20:	learn: 0.6854606	total: 627ms	remaining: 567ms
# 21:	learn: 0.6740769	total: 653ms	remaining: 535ms
# 22:	learn: 0.6638886	total: 681ms	remaining: 503ms
# 23:	learn: 0.6537453	total: 714ms	remaining: 476ms
# 24:	learn: 0.6448019	total: 743ms	remaining: 446ms
# 25:	learn: 0.6352661	total: 773ms	remaining: 416ms
# 26:	learn: 0.6267678	total: 800ms	remaining: 385ms
# 27:	learn: 0.6205430	total: 828ms	remaining: 355ms
# 28:	learn: 0.6141588	total: 855ms	remaining: 324ms
# 29:	learn: 0.6087039	total: 882ms	remaining: 294ms
# 30:	learn: 0.6040295	total: 909ms	remaining: 264ms
# 31:	learn: 0.5992522	total: 943ms	remaining: 236ms
# 32:	learn: 0.5943606	total: 973ms	remaining: 206ms
# 33:	learn: 0.5888697	total: 1000ms	remaining: 176ms
# 34:	learn: 0.5840810	total: 1.03s	remaining: 147ms
# 35:	learn: 0.5788640	total: 1.05s	remaining: 117ms
# 36:	learn: 0.5728358	total: 1.08s	remaining: 87.9ms
# 37:	learn: 0.5670620	total: 1.11s	remaining: 58.5ms
# 38:	learn: 0.5622737	total: 1.14s	remaining: 29.2ms
# 39:	learn: 0.5573893	total: 1.17s	remaining: 0us
# 0:	learn: 1.4446241	total: 39ms	remaining: 1.52s
# 1:	learn: 1.3198900	total: 65.4ms	remaining: 1.24s
# 2:	learn: 1.2319687	total: 92.3ms	remaining: 1.14s
# 3:	learn: 1.1626986	total: 121ms	remaining: 1.09s
# 4:	learn: 1.0981398	total: 148ms	remaining: 1.03s
# 5:	learn: 1.0393922	total: 191ms	remaining: 1.08s
# 6:	learn: 1.0045212	total: 195ms	remaining: 920ms
# 7:	learn: 0.9632012	total: 227ms	remaining: 910ms
# 8:	learn: 0.9232510	total: 254ms	remaining: 876ms
# 9:	learn: 0.8935997	total: 282ms	remaining: 845ms
# 10:	learn: 0.8645654	total: 309ms	remaining: 814ms
# 11:	learn: 0.8394931	total: 338ms	remaining: 789ms
# 12:	learn: 0.8176894	total: 365ms	remaining: 759ms
# 13:	learn: 0.7940663	total: 398ms	remaining: 740ms
# 14:	learn: 0.7739550	total: 429ms	remaining: 716ms
# 15:	learn: 0.7555985	total: 457ms	remaining: 686ms
# 16:	learn: 0.7397219	total: 487ms	remaining: 658ms
# 17:	learn: 0.7263668	total: 513ms	remaining: 627ms
# 18:	learn: 0.7128647	total: 540ms	remaining: 597ms
# 19:	learn: 0.7007181	total: 567ms	remaining: 567ms
# 20:	learn: 0.6877009	total: 593ms	remaining: 537ms
# 21:	learn: 0.6780750	total: 632ms	remaining: 517ms
# 22:	learn: 0.6713368	total: 658ms	remaining: 487ms
# 23:	learn: 0.6623154	total: 689ms	remaining: 459ms
# 24:	learn: 0.6542609	total: 716ms	remaining: 429ms
# 25:	learn: 0.6506600	total: 724ms	remaining: 390ms
# 26:	learn: 0.6399345	total: 750ms	remaining: 361ms
# 27:	learn: 0.6320594	total: 778ms	remaining: 334ms
# 28:	learn: 0.6247559	total: 813ms	remaining: 309ms
# 29:	learn: 0.6196975	total: 863ms	remaining: 288ms
# 30:	learn: 0.6123266	total: 906ms	remaining: 263ms
# 31:	learn: 0.6057450	total: 950ms	remaining: 238ms
# 32:	learn: 0.5986586	total: 996ms	remaining: 211ms
# 33:	learn: 0.5930810	total: 1.05s	remaining: 185ms
# 34:	learn: 0.5861604	total: 1.1s	remaining: 158ms
# 35:	learn: 0.5812972	total: 1.16s	remaining: 128ms
# 36:	learn: 0.5764972	total: 1.21s	remaining: 98.1ms
# 37:	learn: 0.5709381	total: 1.26s	remaining: 66.6ms
# 38:	learn: 0.5665301	total: 1.32s	remaining: 33.8ms
# 39:	learn: 0.5610596	total: 1.37s	remaining: 0us
# 0:	learn: 1.4512935	total: 45.9ms	remaining: 1.79s
# 1:	learn: 1.3436310	total: 77.1ms	remaining: 1.46s
# 2:	learn: 1.2602185	total: 119ms	remaining: 1.46s
# 3:	learn: 1.1827400	total: 146ms	remaining: 1.31s
# 4:	learn: 1.1181738	total: 176ms	remaining: 1.23s
# 5:	learn: 1.0583848	total: 207ms	remaining: 1.17s
# 6:	learn: 1.0131137	total: 239ms	remaining: 1.13s
# 7:	learn: 0.9724161	total: 270ms	remaining: 1.08s
# 8:	learn: 0.9368556	total: 299ms	remaining: 1.03s
# 9:	learn: 0.9055317	total: 337ms	remaining: 1.01s
# 10:	learn: 0.8760661	total: 368ms	remaining: 970ms
# 11:	learn: 0.8491286	total: 399ms	remaining: 932ms
# 12:	learn: 0.8275260	total: 429ms	remaining: 892ms
# 13:	learn: 0.8067368	total: 460ms	remaining: 855ms
# 14:	learn: 0.7854964	total: 492ms	remaining: 819ms
# 15:	learn: 0.7653686	total: 517ms	remaining: 776ms
# 16:	learn: 0.7484356	total: 563ms	remaining: 762ms
# 17:	learn: 0.7362477	total: 597ms	remaining: 730ms
# 18:	learn: 0.7261391	total: 628ms	remaining: 694ms
# 19:	learn: 0.7135761	total: 659ms	remaining: 659ms
# 20:	learn: 0.7001153	total: 691ms	remaining: 625ms
# 21:	learn: 0.6869606	total: 723ms	remaining: 591ms
# 22:	learn: 0.6770768	total: 752ms	remaining: 556ms
# 23:	learn: 0.6681911	total: 785ms	remaining: 523ms
# 24:	learn: 0.6597392	total: 815ms	remaining: 489ms
# 25:	learn: 0.6540702	total: 851ms	remaining: 458ms
# 26:	learn: 0.6463050	total: 883ms	remaining: 425ms
# 27:	learn: 0.6365212	total: 913ms	remaining: 391ms
# 28:	learn: 0.6289860	total: 944ms	remaining: 358ms
# 29:	learn: 0.6211109	total: 975ms	remaining: 325ms
# 30:	learn: 0.6122849	total: 1.01s	remaining: 292ms
# 31:	learn: 0.6055511	total: 1.04s	remaining: 259ms
# 32:	learn: 0.5987211	total: 1.07s	remaining: 227ms
# 33:	learn: 0.5935207	total: 1.1s	remaining: 194ms
# 34:	learn: 0.5881528	total: 1.14s	remaining: 162ms
# 35:	learn: 0.5808841	total: 1.17s	remaining: 130ms
# 36:	learn: 0.5750145	total: 1.19s	remaining: 96.8ms
# 37:	learn: 0.5694557	total: 1.23s	remaining: 65ms
# 38:	learn: 0.5663004	total: 1.27s	remaining: 32.5ms
# 39:	learn: 0.5614344	total: 1.3s	remaining: 0us
# 0:	learn: 1.4483888	total: 52.3ms	remaining: 2.04s
# 1:	learn: 1.3297087	total: 81.6ms	remaining: 1.55s
# 2:	learn: 1.2374239	total: 122ms	remaining: 1.51s
# 3:	learn: 1.1513390	total: 157ms	remaining: 1.42s
# 4:	learn: 1.0894134	total: 191ms	remaining: 1.34s
# 5:	learn: 1.0321416	total: 229ms	remaining: 1.3s
# 6:	learn: 0.9874364	total: 257ms	remaining: 1.21s
# 7:	learn: 0.9498815	total: 289ms	remaining: 1.16s
# 8:	learn: 0.9155340	total: 323ms	remaining: 1.11s
# 9:	learn: 0.8888481	total: 355ms	remaining: 1.06s
# 10:	learn: 0.8596296	total: 383ms	remaining: 1.01s
# 11:	learn: 0.8313776	total: 417ms	remaining: 973ms
# 12:	learn: 0.8058193	total: 449ms	remaining: 933ms
# 13:	learn: 0.7829188	total: 483ms	remaining: 898ms
# 14:	learn: 0.7647476	total: 516ms	remaining: 861ms
# 15:	learn: 0.7478474	total: 554ms	remaining: 832ms
# 16:	learn: 0.7340636	total: 588ms	remaining: 795ms
# 17:	learn: 0.7222575	total: 618ms	remaining: 755ms
# 18:	learn: 0.7094361	total: 654ms	remaining: 722ms
# 19:	learn: 0.6969292	total: 686ms	remaining: 686ms
# 20:	learn: 0.6858366	total: 717ms	remaining: 649ms
# 21:	learn: 0.6751182	total: 749ms	remaining: 613ms
# 22:	learn: 0.6653257	total: 776ms	remaining: 574ms
# 23:	learn: 0.6565654	total: 794ms	remaining: 529ms
# 24:	learn: 0.6456855	total: 812ms	remaining: 487ms
# 25:	learn: 0.6377158	total: 830ms	remaining: 447ms
# 26:	learn: 0.6296667	total: 847ms	remaining: 408ms
# 27:	learn: 0.6222272	total: 865ms	remaining: 371ms
# 28:	learn: 0.6160095	total: 883ms	remaining: 335ms
# 29:	learn: 0.6098308	total: 902ms	remaining: 301ms
# 30:	learn: 0.6016903	total: 921ms	remaining: 267ms
# 31:	learn: 0.5971946	total: 939ms	remaining: 235ms
# 32:	learn: 0.5902335	total: 957ms	remaining: 203ms
# 33:	learn: 0.5837510	total: 977ms	remaining: 172ms
# 34:	learn: 0.5777234	total: 1.01s	remaining: 144ms
# 35:	learn: 0.5724571	total: 1.02s	remaining: 114ms
# 36:	learn: 0.5673798	total: 1.04s	remaining: 84.4ms
# 37:	learn: 0.5633500	total: 1.06s	remaining: 55.7ms
# 38:	learn: 0.5583556	total: 1.07s	remaining: 27.6ms
# 39:	learn: 0.5534876	total: 1.09s	remaining: 0us
# 0:	learn: 1.4499677	total: 25.9ms	remaining: 1.01s
# 1:	learn: 1.3330211	total: 47.9ms	remaining: 909ms
# 2:	learn: 1.2394691	total: 68.1ms	remaining: 840ms
# 3:	learn: 1.1665251	total: 85.7ms	remaining: 771ms
# 4:	learn: 1.1063299	total: 103ms	remaining: 721ms
# 5:	learn: 1.0489385	total: 120ms	remaining: 682ms
# 6:	learn: 1.0022063	total: 140ms	remaining: 661ms
# 7:	learn: 0.9634434	total: 159ms	remaining: 638ms
# 8:	learn: 0.9307825	total: 179ms	remaining: 617ms
# 9:	learn: 0.8977427	total: 197ms	remaining: 591ms
# 10:	learn: 0.8684594	total: 214ms	remaining: 564ms
# 11:	learn: 0.8413402	total: 232ms	remaining: 541ms
# 12:	learn: 0.8223953	total: 253ms	remaining: 525ms
# 13:	learn: 0.7995802	total: 278ms	remaining: 517ms
# 14:	learn: 0.7805847	total: 295ms	remaining: 492ms
# 15:	learn: 0.7635289	total: 313ms	remaining: 469ms
# 16:	learn: 0.7463807	total: 331ms	remaining: 448ms
# 17:	learn: 0.7330677	total: 348ms	remaining: 426ms
# 18:	learn: 0.7210244	total: 372ms	remaining: 411ms
# 19:	learn: 0.7072134	total: 392ms	remaining: 392ms
# 20:	learn: 0.6948809	total: 409ms	remaining: 370ms
# 21:	learn: 0.6851119	total: 429ms	remaining: 351ms
# 22:	learn: 0.6746688	total: 453ms	remaining: 335ms
# 23:	learn: 0.6644447	total: 487ms	remaining: 325ms
# 24:	learn: 0.6546963	total: 505ms	remaining: 303ms
# 25:	learn: 0.6460181	total: 523ms	remaining: 282ms
# 26:	learn: 0.6375874	total: 541ms	remaining: 261ms
# 27:	learn: 0.6288830	total: 559ms	remaining: 240ms
# 28:	learn: 0.6228858	total: 579ms	remaining: 219ms
# 29:	learn: 0.6164405	total: 598ms	remaining: 199ms
# 30:	learn: 0.6094481	total: 616ms	remaining: 179ms
# 31:	learn: 0.6007985	total: 634ms	remaining: 158ms
# 32:	learn: 0.5934644	total: 651ms	remaining: 138ms
# 33:	learn: 0.5880601	total: 669ms	remaining: 118ms
# 34:	learn: 0.5825092	total: 691ms	remaining: 98.7ms
# 35:	learn: 0.5767681	total: 714ms	remaining: 79.3ms
# 36:	learn: 0.5716504	total: 733ms	remaining: 59.4ms
# 37:	learn: 0.5670834	total: 751ms	remaining: 39.5ms
# 38:	learn: 0.5621552	total: 769ms	remaining: 19.7ms
# 39:	learn: 0.5568650	total: 787ms	remaining: 0us
# 0:	learn: 1.4494839	total: 27.1ms	remaining: 1.06s
# 1:	learn: 1.3340159	total: 45ms	remaining: 855ms
# 2:	learn: 1.2446862	total: 62.3ms	remaining: 768ms
# 3:	learn: 1.1694421	total: 92.5ms	remaining: 832ms
# 4:	learn: 1.1058438	total: 113ms	remaining: 789ms
# 5:	learn: 1.0504697	total: 130ms	remaining: 739ms
# 6:	learn: 1.0046636	total: 149ms	remaining: 704ms
# 7:	learn: 0.9633403	total: 168ms	remaining: 673ms
# 8:	learn: 0.9272883	total: 186ms	remaining: 641ms
# 9:	learn: 0.8930848	total: 205ms	remaining: 614ms
# 10:	learn: 0.8647699	total: 222ms	remaining: 586ms
# 11:	learn: 0.8386469	total: 241ms	remaining: 561ms
# 12:	learn: 0.8149693	total: 258ms	remaining: 536ms
# 13:	learn: 0.7961424	total: 276ms	remaining: 512ms
# 14:	learn: 0.7787806	total: 295ms	remaining: 492ms
# 15:	learn: 0.7598554	total: 321ms	remaining: 482ms
# 16:	learn: 0.7446742	total: 341ms	remaining: 462ms
# 17:	learn: 0.7317763	total: 358ms	remaining: 438ms
# 18:	learn: 0.7170089	total: 376ms	remaining: 415ms
# 19:	learn: 0.7058192	total: 393ms	remaining: 393ms
# 20:	learn: 0.6963090	total: 411ms	remaining: 372ms
# 21:	learn: 0.6856895	total: 428ms	remaining: 351ms
# 22:	learn: 0.6732062	total: 446ms	remaining: 330ms
# 23:	learn: 0.6632154	total: 463ms	remaining: 309ms
# 24:	learn: 0.6527717	total: 481ms	remaining: 288ms
# 25:	learn: 0.6431473	total: 501ms	remaining: 270ms
# 26:	learn: 0.6324515	total: 525ms	remaining: 253ms
# 27:	learn: 0.6261414	total: 544ms	remaining: 233ms
# 28:	learn: 0.6193899	total: 562ms	remaining: 213ms
# 29:	learn: 0.6118609	total: 580ms	remaining: 193ms
# 30:	learn: 0.6045227	total: 597ms	remaining: 173ms
# 31:	learn: 0.5994178	total: 614ms	remaining: 154ms
# 32:	learn: 0.5925930	total: 635ms	remaining: 135ms
# 33:	learn: 0.5871224	total: 662ms	remaining: 117ms
# 34:	learn: 0.5819111	total: 680ms	remaining: 97.1ms
# 35:	learn: 0.5761534	total: 697ms	remaining: 77.5ms
# 36:	learn: 0.5721528	total: 719ms	remaining: 58.3ms
# 37:	learn: 0.5681274	total: 744ms	remaining: 39.2ms
# 38:	learn: 0.5632839	total: 762ms	remaining: 19.5ms
# 39:	learn: 0.5586014	total: 780ms	remaining: 0us
# 0:	learn: 1.4455647	total: 25.8ms	remaining: 1s
# 1:	learn: 1.3253168	total: 43.8ms	remaining: 832ms
# 2:	learn: 1.2398724	total: 61.6ms	remaining: 760ms
# 3:	learn: 1.1616100	total: 79.8ms	remaining: 718ms
# 4:	learn: 1.1003170	total: 97.4ms	remaining: 682ms
# 5:	learn: 1.0409696	total: 122ms	remaining: 692ms
# 6:	learn: 0.9929713	total: 140ms	remaining: 659ms
# 7:	learn: 0.9550826	total: 157ms	remaining: 628ms
# 8:	learn: 0.9224283	total: 174ms	remaining: 600ms
# 9:	learn: 0.8918918	total: 192ms	remaining: 576ms
# 10:	learn: 0.8602493	total: 214ms	remaining: 565ms
# 11:	learn: 0.8377398	total: 234ms	remaining: 546ms
# 12:	learn: 0.8138940	total: 252ms	remaining: 523ms
# 13:	learn: 0.7931489	total: 270ms	remaining: 501ms
# 14:	learn: 0.7710737	total: 287ms	remaining: 478ms
# 15:	learn: 0.7556883	total: 305ms	remaining: 457ms
# 16:	learn: 0.7393540	total: 324ms	remaining: 439ms
# 17:	learn: 0.7235281	total: 347ms	remaining: 424ms
# 18:	learn: 0.7104891	total: 364ms	remaining: 403ms
# 19:	learn: 0.6966951	total: 383ms	remaining: 383ms
# 20:	learn: 0.6860642	total: 401ms	remaining: 363ms
# 21:	learn: 0.6747347	total: 424ms	remaining: 347ms
# 22:	learn: 0.6639534	total: 443ms	remaining: 328ms
# 23:	learn: 0.6531770	total: 461ms	remaining: 308ms
# 24:	learn: 0.6456753	total: 479ms	remaining: 287ms
# 25:	learn: 0.6388154	total: 496ms	remaining: 267ms
# 26:	learn: 0.6315989	total: 516ms	remaining: 249ms
# 27:	learn: 0.6248554	total: 539ms	remaining: 231ms
# 28:	learn: 0.6167638	total: 558ms	remaining: 212ms
# 29:	learn: 0.6096236	total: 575ms	remaining: 192ms
# 30:	learn: 0.6017955	total: 592ms	remaining: 172ms
# 31:	learn: 0.5955809	total: 610ms	remaining: 152ms
# 32:	learn: 0.5885035	total: 627ms	remaining: 133ms
# 33:	learn: 0.5827688	total: 645ms	remaining: 114ms
# 34:	learn: 0.5802081	total: 648ms	remaining: 92.5ms
# 35:	learn: 0.5750337	total: 668ms	remaining: 74.2ms
# 36:	learn: 0.5711777	total: 685ms	remaining: 55.5ms
# 37:	learn: 0.5675122	total: 702ms	remaining: 37ms
# 38:	learn: 0.5631436	total: 721ms	remaining: 18.5ms
# 39:	learn: 0.5588963	total: 742ms	remaining: 0us
# 0:	learn: 1.4461070	total: 31.5ms	remaining: 1.23s
# 1:	learn: 1.3282004	total: 65.4ms	remaining: 1.24s
# 2:	learn: 1.2306390	total: 88.1ms	remaining: 1.09s
# 3:	learn: 1.1576311	total: 111ms	remaining: 1s
# 4:	learn: 1.0972008	total: 132ms	remaining: 924ms
# 5:	learn: 1.0432150	total: 153ms	remaining: 866ms
# 6:	learn: 0.9963865	total: 182ms	remaining: 856ms
# 7:	learn: 0.9555714	total: 209ms	remaining: 834ms
# 8:	learn: 0.9206861	total: 229ms	remaining: 788ms
# 9:	learn: 0.8887782	total: 249ms	remaining: 748ms
# 10:	learn: 0.8608190	total: 270ms	remaining: 711ms
# 11:	learn: 0.8354603	total: 290ms	remaining: 676ms
# 12:	learn: 0.8103152	total: 312ms	remaining: 648ms
# 13:	learn: 0.7913366	total: 335ms	remaining: 622ms
# 14:	learn: 0.7753390	total: 356ms	remaining: 593ms
# 15:	learn: 0.7579120	total: 377ms	remaining: 565ms
# 16:	learn: 0.7395979	total: 407ms	remaining: 551ms
# 17:	learn: 0.7236175	total: 429ms	remaining: 525ms
# 18:	learn: 0.7084604	total: 450ms	remaining: 497ms
# 19:	learn: 0.6943205	total: 471ms	remaining: 471ms
# 20:	learn: 0.6828812	total: 491ms	remaining: 444ms
# 21:	learn: 0.6727143	total: 512ms	remaining: 419ms
# 22:	learn: 0.6645442	total: 538ms	remaining: 398ms
# 23:	learn: 0.6576725	total: 559ms	remaining: 372ms
# 24:	learn: 0.6460577	total: 579ms	remaining: 347ms
# 25:	learn: 0.6357013	total: 599ms	remaining: 323ms
# 26:	learn: 0.6265911	total: 628ms	remaining: 302ms
# 27:	learn: 0.6196384	total: 649ms	remaining: 278ms
# 28:	learn: 0.6123706	total: 669ms	remaining: 254ms
# 29:	learn: 0.6076402	total: 689ms	remaining: 230ms
# 30:	learn: 0.6005518	total: 713ms	remaining: 207ms
# 31:	learn: 0.5916858	total: 734ms	remaining: 183ms
# 32:	learn: 0.5870019	total: 754ms	remaining: 160ms
# 33:	learn: 0.5808016	total: 776ms	remaining: 137ms
# 34:	learn: 0.5755474	total: 796ms	remaining: 114ms
# 35:	learn: 0.5703670	total: 817ms	remaining: 90.8ms
# 36:	learn: 0.5644513	total: 843ms	remaining: 68.4ms
# 37:	learn: 0.5597036	total: 864ms	remaining: 45.5ms
# 38:	learn: 0.5545765	total: 884ms	remaining: 22.7ms
# 39:	learn: 0.5524691	total: 908ms	remaining: 0us
# 0:	learn: 1.4508104	total: 32.7ms	remaining: 1.27s
# 1:	learn: 1.3337120	total: 53.8ms	remaining: 1.02s
# 2:	learn: 1.2446597	total: 75.6ms	remaining: 933ms
# 3:	learn: 1.1730402	total: 98ms	remaining: 882ms
# 4:	learn: 1.1073738	total: 140ms	remaining: 982ms
# 5:	learn: 1.0537529	total: 162ms	remaining: 916ms
# 6:	learn: 1.0025160	total: 183ms	remaining: 862ms
# 7:	learn: 0.9599549	total: 206ms	remaining: 824ms
# 8:	learn: 0.9214013	total: 229ms	remaining: 790ms
# 9:	learn: 0.8893150	total: 253ms	remaining: 760ms
# 10:	learn: 0.8623797	total: 275ms	remaining: 725ms
# 11:	learn: 0.8349272	total: 296ms	remaining: 692ms
# 12:	learn: 0.8116626	total: 328ms	remaining: 682ms
# 13:	learn: 0.7903776	total: 352ms	remaining: 653ms
# 14:	learn: 0.7716725	total: 372ms	remaining: 620ms
# 15:	learn: 0.7552526	total: 394ms	remaining: 590ms
# 16:	learn: 0.7391674	total: 415ms	remaining: 562ms
# 17:	learn: 0.7259969	total: 438ms	remaining: 535ms
# 18:	learn: 0.7122447	total: 459ms	remaining: 508ms
# 19:	learn: 0.6992827	total: 480ms	remaining: 480ms
# 20:	learn: 0.6887947	total: 504ms	remaining: 456ms
# 21:	learn: 0.6761171	total: 527ms	remaining: 431ms
# 22:	learn: 0.6654306	total: 555ms	remaining: 410ms
# 23:	learn: 0.6569912	total: 576ms	remaining: 384ms
# 24:	learn: 0.6486849	total: 597ms	remaining: 358ms
# 25:	learn: 0.6391040	total: 620ms	remaining: 334ms
# 26:	learn: 0.6315170	total: 641ms	remaining: 309ms
# 27:	learn: 0.6253607	total: 662ms	remaining: 284ms
# 28:	learn: 0.6201286	total: 683ms	remaining: 259ms
# 29:	learn: 0.6143498	total: 705ms	remaining: 235ms
# 30:	learn: 0.6070737	total: 727ms	remaining: 211ms
# 31:	learn: 0.5988161	total: 749ms	remaining: 187ms
# 32:	learn: 0.5925559	total: 784ms	remaining: 166ms
# 33:	learn: 0.5877735	total: 806ms	remaining: 142ms
# 34:	learn: 0.5821370	total: 827ms	remaining: 118ms
# 35:	learn: 0.5756233	total: 852ms	remaining: 94.7ms
# 36:	learn: 0.5714892	total: 873ms	remaining: 70.8ms
# 37:	learn: 0.5670003	total: 894ms	remaining: 47ms
# 38:	learn: 0.5618879	total: 915ms	remaining: 23.5ms
# 39:	learn: 0.5587006	total: 936ms	remaining: 0us
# 0:	learn: 1.4625329	total: 37.6ms	remaining: 1.47s
# 1:	learn: 1.3477288	total: 58.5ms	remaining: 1.11s
# 2:	learn: 1.2537009	total: 79.4ms	remaining: 980ms
# 3:	learn: 1.1788904	total: 107ms	remaining: 959ms
# 4:	learn: 1.1110492	total: 127ms	remaining: 890ms
# 5:	learn: 1.0549795	total: 148ms	remaining: 837ms
# 6:	learn: 1.0015179	total: 181ms	remaining: 855ms
# 7:	learn: 0.9594096	total: 203ms	remaining: 813ms
# 8:	learn: 0.9236101	total: 223ms	remaining: 770ms
# 9:	learn: 0.8914601	total: 255ms	remaining: 764ms
# 10:	learn: 0.8655814	total: 275ms	remaining: 726ms
# 11:	learn: 0.8361146	total: 296ms	remaining: 691ms
# 12:	learn: 0.8125652	total: 317ms	remaining: 659ms
# 13:	learn: 0.7902787	total: 339ms	remaining: 630ms
# 14:	learn: 0.7704697	total: 362ms	remaining: 604ms
# 15:	learn: 0.7540184	total: 384ms	remaining: 576ms
# 16:	learn: 0.7371696	total: 405ms	remaining: 549ms
# 17:	learn: 0.7208355	total: 427ms	remaining: 522ms
# 18:	learn: 0.7068986	total: 450ms	remaining: 498ms
# 19:	learn: 0.6933374	total: 481ms	remaining: 481ms
# 20:	learn: 0.6834891	total: 502ms	remaining: 454ms
# 21:	learn: 0.6744320	total: 522ms	remaining: 427ms
# 22:	learn: 0.6629787	total: 544ms	remaining: 402ms
# 23:	learn: 0.6543036	total: 568ms	remaining: 378ms
# 24:	learn: 0.6457449	total: 588ms	remaining: 353ms
# 25:	learn: 0.6378527	total: 609ms	remaining: 328ms
# 26:	learn: 0.6316501	total: 630ms	remaining: 303ms
# 27:	learn: 0.6247855	total: 649ms	remaining: 278ms
# 28:	learn: 0.6151838	total: 670ms	remaining: 254ms
# 29:	learn: 0.6087908	total: 697ms	remaining: 232ms
# 30:	learn: 0.6023609	total: 718ms	remaining: 208ms
# 31:	learn: 0.5965659	total: 738ms	remaining: 184ms
# 32:	learn: 0.5923834	total: 758ms	remaining: 161ms
# 33:	learn: 0.5878648	total: 783ms	remaining: 138ms
# 34:	learn: 0.5800053	total: 804ms	remaining: 115ms
# 35:	learn: 0.5756194	total: 825ms	remaining: 91.7ms
# 36:	learn: 0.5705804	total: 846ms	remaining: 68.6ms
# 37:	learn: 0.5647955	total: 866ms	remaining: 45.6ms
# 38:	learn: 0.5592337	total: 887ms	remaining: 22.7ms
# 39:	learn: 0.5533510	total: 916ms	remaining: 0us
# 0:	learn: 1.4529097	total: 32.8ms	remaining: 1.28s
# 1:	learn: 1.3353502	total: 54.9ms	remaining: 1.04s
# 2:	learn: 1.2459019	total: 76.9ms	remaining: 949ms
# 3:	learn: 1.1735321	total: 97.4ms	remaining: 877ms
# 4:	learn: 1.1048080	total: 117ms	remaining: 821ms
# 5:	learn: 1.0526645	total: 140ms	remaining: 792ms
# 6:	learn: 1.0012004	total: 160ms	remaining: 757ms
# 7:	learn: 0.9618907	total: 189ms	remaining: 757ms
# 8:	learn: 0.9278088	total: 209ms	remaining: 720ms
# 9:	learn: 0.8916528	total: 238ms	remaining: 713ms
# 10:	learn: 0.8657629	total: 262ms	remaining: 691ms
# 11:	learn: 0.8417678	total: 286ms	remaining: 668ms
# 12:	learn: 0.8200315	total: 312ms	remaining: 648ms
# 13:	learn: 0.7976591	total: 333ms	remaining: 618ms
# 14:	learn: 0.7781085	total: 352ms	remaining: 587ms
# 15:	learn: 0.7584503	total: 374ms	remaining: 560ms
# 16:	learn: 0.7429935	total: 403ms	remaining: 545ms
# 17:	learn: 0.7279818	total: 424ms	remaining: 518ms
# 18:	learn: 0.7148396	total: 445ms	remaining: 492ms
# 19:	learn: 0.7012089	total: 466ms	remaining: 466ms
# 20:	learn: 0.6876335	total: 488ms	remaining: 442ms
# 21:	learn: 0.6765195	total: 511ms	remaining: 418ms
# 22:	learn: 0.6680530	total: 533ms	remaining: 394ms
# 23:	learn: 0.6617703	total: 553ms	remaining: 368ms
# 24:	learn: 0.6495718	total: 573ms	remaining: 344ms
# 25:	learn: 0.6378032	total: 594ms	remaining: 320ms
# 26:	learn: 0.6304611	total: 622ms	remaining: 299ms
# 27:	learn: 0.6247001	total: 642ms	remaining: 275ms
# 28:	learn: 0.6167949	total: 663ms	remaining: 252ms
# 29:	learn: 0.6102464	total: 684ms	remaining: 228ms
# 30:	learn: 0.6029523	total: 704ms	remaining: 204ms
# 31:	learn: 0.5970356	total: 724ms	remaining: 181ms
# 32:	learn: 0.5903049	total: 744ms	remaining: 158ms
# 33:	learn: 0.5855080	total: 765ms	remaining: 135ms
# 34:	learn: 0.5796558	total: 788ms	remaining: 113ms
# 35:	learn: 0.5738828	total: 812ms	remaining: 90.2ms
# 36:	learn: 0.5687926	total: 839ms	remaining: 68ms
# 37:	learn: 0.5638408	total: 859ms	remaining: 45.2ms
# 38:	learn: 0.5595164	total: 879ms	remaining: 22.5ms
# 39:	learn: 0.5538163	total: 900ms	remaining: 0us
# 0:	learn: 1.4476815	total: 31.6ms	remaining: 1.23s
# 1:	learn: 1.3390134	total: 54.4ms	remaining: 1.03s
# 2:	learn: 1.2394095	total: 80.5ms	remaining: 993ms
# 3:	learn: 1.1648195	total: 106ms	remaining: 957ms
# 4:	learn: 1.1020148	total: 133ms	remaining: 933ms
# 5:	learn: 1.0432711	total: 154ms	remaining: 873ms
# 6:	learn: 0.9974469	total: 177ms	remaining: 833ms
# 7:	learn: 0.9550530	total: 198ms	remaining: 791ms
# 8:	learn: 0.9217404	total: 219ms	remaining: 753ms
# 9:	learn: 0.8883114	total: 240ms	remaining: 720ms
# 10:	learn: 0.8617087	total: 261ms	remaining: 687ms
# 11:	learn: 0.8363212	total: 281ms	remaining: 656ms
# 12:	learn: 0.8125073	total: 311ms	remaining: 647ms
# 13:	learn: 0.7895615	total: 344ms	remaining: 638ms
# 14:	learn: 0.7670236	total: 365ms	remaining: 608ms
# 15:	learn: 0.7491344	total: 388ms	remaining: 582ms
# 16:	learn: 0.7332025	total: 412ms	remaining: 558ms
# 17:	learn: 0.7157802	total: 435ms	remaining: 531ms
# 18:	learn: 0.7030836	total: 456ms	remaining: 504ms
# 19:	learn: 0.6936018	total: 478ms	remaining: 478ms
# 20:	learn: 0.6798932	total: 500ms	remaining: 453ms
# 21:	learn: 0.6688281	total: 534ms	remaining: 437ms
# 22:	learn: 0.6581059	total: 555ms	remaining: 410ms
# 23:	learn: 0.6476211	total: 576ms	remaining: 384ms
# 24:	learn: 0.6380136	total: 597ms	remaining: 358ms
# 25:	learn: 0.6313749	total: 623ms	remaining: 335ms
# 26:	learn: 0.6234404	total: 645ms	remaining: 310ms
# 27:	learn: 0.6150434	total: 666ms	remaining: 285ms
# 28:	learn: 0.6072912	total: 687ms	remaining: 261ms
# 29:	learn: 0.5999744	total: 708ms	remaining: 236ms
# 30:	learn: 0.5923659	total: 730ms	remaining: 212ms
# 31:	learn: 0.5858102	total: 757ms	remaining: 189ms
# 32:	learn: 0.5797039	total: 778ms	remaining: 165ms
# 33:	learn: 0.5744010	total: 798ms	remaining: 141ms
# 34:	learn: 0.5683586	total: 819ms	remaining: 117ms
# 35:	learn: 0.5641268	total: 844ms	remaining: 93.7ms
# 36:	learn: 0.5581717	total: 867ms	remaining: 70.3ms
# 37:	learn: 0.5521732	total: 889ms	remaining: 46.8ms
# 38:	learn: 0.5476228	total: 910ms	remaining: 23.3ms
# 39:	learn: 0.5421859	total: 932ms	remaining: 0us
# 0:	learn: 1.4491133	total: 33.7ms	remaining: 1.31s
# 1:	learn: 1.3368581	total: 56.5ms	remaining: 1.07s
# 2:	learn: 1.2426923	total: 86.6ms	remaining: 1.07s
# 3:	learn: 1.1687236	total: 110ms	remaining: 986ms
# 4:	learn: 1.1085232	total: 133ms	remaining: 928ms
# 5:	learn: 1.0493252	total: 156ms	remaining: 882ms
# 6:	learn: 1.0041161	total: 178ms	remaining: 840ms
# 7:	learn: 0.9662056	total: 202ms	remaining: 809ms
# 8:	learn: 0.9284944	total: 225ms	remaining: 774ms
# 9:	learn: 0.8973155	total: 256ms	remaining: 768ms
# 10:	learn: 0.8685327	total: 279ms	remaining: 734ms
# 11:	learn: 0.8436686	total: 305ms	remaining: 712ms
# 12:	learn: 0.8211900	total: 329ms	remaining: 684ms
# 13:	learn: 0.8007644	total: 363ms	remaining: 674ms
# 14:	learn: 0.7819558	total: 388ms	remaining: 647ms
# 15:	learn: 0.7632421	total: 411ms	remaining: 617ms
# 16:	learn: 0.7460438	total: 434ms	remaining: 587ms
# 17:	learn: 0.7335921	total: 462ms	remaining: 564ms
# 18:	learn: 0.7193603	total: 487ms	remaining: 539ms
# 19:	learn: 0.7089423	total: 510ms	remaining: 510ms
# 20:	learn: 0.6956544	total: 535ms	remaining: 484ms
# 21:	learn: 0.6847781	total: 558ms	remaining: 457ms
# 22:	learn: 0.6739757	total: 581ms	remaining: 429ms
# 23:	learn: 0.6661328	total: 605ms	remaining: 403ms
# 24:	learn: 0.6573806	total: 627ms	remaining: 376ms
# 25:	learn: 0.6497220	total: 650ms	remaining: 350ms
# 26:	learn: 0.6408510	total: 680ms	remaining: 327ms
# 27:	learn: 0.6336549	total: 704ms	remaining: 302ms
# 28:	learn: 0.6256327	total: 729ms	remaining: 277ms
# 29:	learn: 0.6183323	total: 752ms	remaining: 251ms
# 30:	learn: 0.6113055	total: 775ms	remaining: 225ms
# 31:	learn: 0.6030279	total: 798ms	remaining: 200ms
# 32:	learn: 0.5977833	total: 821ms	remaining: 174ms
# 33:	learn: 0.5890531	total: 844ms	remaining: 149ms
# 34:	learn: 0.5822331	total: 867ms	remaining: 124ms
# 35:	learn: 0.5762056	total: 898ms	remaining: 99.8ms
# 36:	learn: 0.5708251	total: 921ms	remaining: 74.7ms
# 37:	learn: 0.5655060	total: 945ms	remaining: 49.7ms
# 38:	learn: 0.5610128	total: 971ms	remaining: 24.9ms
# 39:	learn: 0.5578342	total: 993ms	remaining: 0us
# 0:	learn: 1.4382127	total: 34.6ms	remaining: 1.35s
# 1:	learn: 1.3367398	total: 59.6ms	remaining: 1.13s
# 2:	learn: 1.2339511	total: 93.3ms	remaining: 1.15s
# 3:	learn: 1.1659012	total: 117ms	remaining: 1.05s
# 4:	learn: 1.1011631	total: 141ms	remaining: 989ms
# 5:	learn: 1.0471965	total: 170ms	remaining: 961ms
# 6:	learn: 1.0009629	total: 195ms	remaining: 917ms
# 7:	learn: 0.9592720	total: 218ms	remaining: 871ms
# 8:	learn: 0.9241217	total: 240ms	remaining: 828ms
# 9:	learn: 0.8945377	total: 264ms	remaining: 791ms
# 10:	learn: 0.8686671	total: 286ms	remaining: 754ms
# 11:	learn: 0.8414687	total: 321ms	remaining: 749ms
# 12:	learn: 0.8209671	total: 357ms	remaining: 742ms
# 13:	learn: 0.8000210	total: 382ms	remaining: 709ms
# 14:	learn: 0.7804837	total: 405ms	remaining: 676ms
# 15:	learn: 0.7608428	total: 429ms	remaining: 643ms
# 16:	learn: 0.7424833	total: 452ms	remaining: 611ms
# 17:	learn: 0.7289315	total: 476ms	remaining: 582ms
# 18:	learn: 0.7166972	total: 501ms	remaining: 554ms
# 19:	learn: 0.7018249	total: 529ms	remaining: 529ms
# 20:	learn: 0.6912087	total: 559ms	remaining: 506ms
# 21:	learn: 0.6813976	total: 583ms	remaining: 477ms
# 22:	learn: 0.6691843	total: 608ms	remaining: 449ms
# 23:	learn: 0.6604829	total: 631ms	remaining: 421ms
# 24:	learn: 0.6495542	total: 654ms	remaining: 392ms
# 25:	learn: 0.6409441	total: 677ms	remaining: 364ms
# 26:	learn: 0.6323131	total: 700ms	remaining: 337ms
# 27:	learn: 0.6255238	total: 723ms	remaining: 310ms
# 28:	learn: 0.6177565	total: 754ms	remaining: 286ms
# 29:	learn: 0.6102567	total: 777ms	remaining: 259ms
# 30:	learn: 0.6048030	total: 800ms	remaining: 232ms
# 31:	learn: 0.5973330	total: 822ms	remaining: 205ms
# 32:	learn: 0.5906315	total: 847ms	remaining: 180ms
# 33:	learn: 0.5840857	total: 870ms	remaining: 153ms
# 34:	learn: 0.5772669	total: 892ms	remaining: 127ms
# 35:	learn: 0.5724650	total: 921ms	remaining: 102ms
# 36:	learn: 0.5681671	total: 944ms	remaining: 76.5ms
# 37:	learn: 0.5609323	total: 973ms	remaining: 51.2ms
# 38:	learn: 0.5570324	total: 998ms	remaining: 25.6ms
# 39:	learn: 0.5521419	total: 1.02s	remaining: 0us
# 0:	learn: 1.4459485	total: 35.5ms	remaining: 1.39s
# 1:	learn: 1.3291449	total: 62.1ms	remaining: 1.18s
# 2:	learn: 1.2310460	total: 87.2ms	remaining: 1.07s
# 3:	learn: 1.1562470	total: 111ms	remaining: 995ms
# 4:	learn: 1.0950657	total: 145ms	remaining: 1.01s
# 5:	learn: 1.0411990	total: 175ms	remaining: 990ms
# 6:	learn: 0.9957258	total: 213ms	remaining: 1s
# 7:	learn: 0.9573006	total: 251ms	remaining: 1s
# 8:	learn: 0.9245444	total: 294ms	remaining: 1.01s
# 9:	learn: 0.8908354	total: 347ms	remaining: 1.04s
# 10:	learn: 0.8641845	total: 392ms	remaining: 1.03s
# 11:	learn: 0.8392298	total: 437ms	remaining: 1.02s
# 12:	learn: 0.8165773	total: 479ms	remaining: 995ms
# 13:	learn: 0.8005878	total: 524ms	remaining: 974ms
# 14:	learn: 0.7816959	total: 581ms	remaining: 968ms
# 15:	learn: 0.7645649	total: 624ms	remaining: 936ms
# 16:	learn: 0.7486236	total: 665ms	remaining: 900ms
# 17:	learn: 0.7341458	total: 707ms	remaining: 865ms
# 18:	learn: 0.7221434	total: 752ms	remaining: 831ms
# 19:	learn: 0.7103151	total: 807ms	remaining: 807ms
# 20:	learn: 0.6986463	total: 855ms	remaining: 774ms
# 21:	learn: 0.6881951	total: 897ms	remaining: 734ms
# 22:	learn: 0.6761314	total: 939ms	remaining: 694ms
# 23:	learn: 0.6669686	total: 983ms	remaining: 656ms
# 24:	learn: 0.6589760	total: 1.04s	remaining: 624ms
# 25:	learn: 0.6510932	total: 1.08s	remaining: 583ms
# 26:	learn: 0.6416969	total: 1.12s	remaining: 542ms
# 27:	learn: 0.6323410	total: 1.16s	remaining: 498ms
# 28:	learn: 0.6226654	total: 1.2s	remaining: 456ms
# 29:	learn: 0.6146234	total: 1.26s	remaining: 419ms
# 30:	learn: 0.6070668	total: 1.3s	remaining: 378ms
# 31:	learn: 0.6008675	total: 1.35s	remaining: 337ms
# 32:	learn: 0.5943960	total: 1.39s	remaining: 294ms
# 33:	learn: 0.5895539	total: 1.43s	remaining: 252ms
# 34:	learn: 0.5850324	total: 1.48s	remaining: 211ms
# 35:	learn: 0.5788445	total: 1.52s	remaining: 169ms
# 36:	learn: 0.5733064	total: 1.56s	remaining: 127ms
# 37:	learn: 0.5683268	total: 1.6s	remaining: 84.4ms
# 38:	learn: 0.5640072	total: 1.65s	remaining: 42.2ms
# 39:	learn: 0.5597641	total: 1.69s	remaining: 0us
# 0:	learn: 1.4339860	total: 56ms	remaining: 2.19s
# 1:	learn: 1.3108589	total: 94ms	remaining: 1.79s
# 2:	learn: 1.2199929	total: 150ms	remaining: 1.85s
# 3:	learn: 1.1426000	total: 186ms	remaining: 1.67s
# 4:	learn: 1.0829887	total: 217ms	remaining: 1.52s
# 5:	learn: 1.0318659	total: 261ms	remaining: 1.48s
# 6:	learn: 0.9863711	total: 307ms	remaining: 1.45s
# 7:	learn: 0.9471960	total: 347ms	remaining: 1.39s
# 8:	learn: 0.9130714	total: 391ms	remaining: 1.34s
# 9:	learn: 0.8823666	total: 432ms	remaining: 1.3s
# 10:	learn: 0.8541170	total: 472ms	remaining: 1.24s
# 11:	learn: 0.8295092	total: 516ms	remaining: 1.2s
# 12:	learn: 0.8109330	total: 565ms	remaining: 1.17s
# 13:	learn: 0.7897175	total: 612ms	remaining: 1.14s
# 14:	learn: 0.7703702	total: 652ms	remaining: 1.09s
# 15:	learn: 0.7549199	total: 695ms	remaining: 1.04s
# 16:	learn: 0.7373609	total: 742ms	remaining: 1s
# 17:	learn: 0.7233972	total: 786ms	remaining: 961ms
# 18:	learn: 0.7082277	total: 831ms	remaining: 918ms
# 19:	learn: 0.6963495	total: 874ms	remaining: 874ms
# 20:	learn: 0.6864756	total: 919ms	remaining: 832ms
# 21:	learn: 0.6766462	total: 963ms	remaining: 788ms
# 22:	learn: 0.6691409	total: 1.02s	remaining: 754ms
# 23:	learn: 0.6593107	total: 1.06s	remaining: 709ms
# 24:	learn: 0.6493239	total: 1.1s	remaining: 662ms
# 25:	learn: 0.6407180	total: 1.13s	remaining: 607ms
# 26:	learn: 0.6322647	total: 1.15s	remaining: 555ms
# 27:	learn: 0.6263426	total: 1.18s	remaining: 505ms
# 28:	learn: 0.6217071	total: 1.2s	remaining: 456ms
# 29:	learn: 0.6160282	total: 1.23s	remaining: 409ms
# 30:	learn: 0.6119035	total: 1.25s	remaining: 364ms
# 31:	learn: 0.6072121	total: 1.28s	remaining: 320ms
# 32:	learn: 0.6007474	total: 1.3s	remaining: 276ms
# 33:	learn: 0.5934287	total: 1.32s	remaining: 234ms
# 34:	learn: 0.5866389	total: 1.35s	remaining: 192ms
# 35:	learn: 0.5803480	total: 1.37s	remaining: 153ms
# 36:	learn: 0.5746001	total: 1.4s	remaining: 113ms
# 37:	learn: 0.5672473	total: 1.42s	remaining: 74.8ms
# 38:	learn: 0.5624176	total: 1.45s	remaining: 37.2ms
# 39:	learn: 0.5577406	total: 1.47s	remaining: 0us
# 0:	learn: 1.4329220	total: 35.2ms	remaining: 1.37s
# 1:	learn: 1.3155349	total: 60.2ms	remaining: 1.14s
# 2:	learn: 1.2200521	total: 84.1ms	remaining: 1.04s
# 3:	learn: 1.1475201	total: 116ms	remaining: 1.04s
# 4:	learn: 1.0852320	total: 153ms	remaining: 1.07s
# 5:	learn: 1.0302922	total: 181ms	remaining: 1.02s
# 6:	learn: 0.9843671	total: 206ms	remaining: 969ms
# 7:	learn: 0.9421106	total: 230ms	remaining: 919ms
# 8:	learn: 0.9067566	total: 254ms	remaining: 875ms
# 9:	learn: 0.8709637	total: 279ms	remaining: 838ms
# 10:	learn: 0.8473740	total: 304ms	remaining: 802ms
# 11:	learn: 0.8227486	total: 328ms	remaining: 766ms
# 12:	learn: 0.7980498	total: 360ms	remaining: 748ms
# 13:	learn: 0.7780885	total: 385ms	remaining: 714ms
# 14:	learn: 0.7599764	total: 408ms	remaining: 680ms
# 15:	learn: 0.7449644	total: 432ms	remaining: 648ms
# 16:	learn: 0.7293924	total: 462ms	remaining: 625ms
# 17:	learn: 0.7142747	total: 487ms	remaining: 595ms
# 18:	learn: 0.7023051	total: 514ms	remaining: 568ms
# 19:	learn: 0.6890882	total: 538ms	remaining: 538ms
# 20:	learn: 0.6783165	total: 566ms	remaining: 512ms
# 21:	learn: 0.6685223	total: 598ms	remaining: 489ms
# 22:	learn: 0.6570735	total: 622ms	remaining: 460ms
# 23:	learn: 0.6463551	total: 649ms	remaining: 432ms
# 24:	learn: 0.6369279	total: 673ms	remaining: 404ms
# 25:	learn: 0.6274483	total: 699ms	remaining: 376ms
# 26:	learn: 0.6195948	total: 723ms	remaining: 348ms
# 27:	learn: 0.6138555	total: 749ms	remaining: 321ms
# 28:	learn: 0.6060151	total: 780ms	remaining: 296ms
# 29:	learn: 0.6009614	total: 808ms	remaining: 269ms
# 30:	learn: 0.5945130	total: 832ms	remaining: 242ms
# 31:	learn: 0.5862581	total: 858ms	remaining: 214ms
# 32:	learn: 0.5810237	total: 882ms	remaining: 187ms
# 33:	learn: 0.5761538	total: 907ms	remaining: 160ms
# 34:	learn: 0.5702961	total: 931ms	remaining: 133ms
# 35:	learn: 0.5652091	total: 955ms	remaining: 106ms
# 36:	learn: 0.5599296	total: 984ms	remaining: 79.8ms
# 37:	learn: 0.5549352	total: 1.01s	remaining: 53.3ms
# 38:	learn: 0.5502672	total: 1.04s	remaining: 26.6ms
# 39:	learn: 0.5455665	total: 1.06s	remaining: 0us
# 0:	learn: 1.4575131	total: 53.2ms	remaining: 2.07s
# 1:	learn: 1.3398630	total: 86.8ms	remaining: 1.65s
# 2:	learn: 1.2475857	total: 114ms	remaining: 1.41s
# 3:	learn: 1.1768872	total: 147ms	remaining: 1.33s
# 4:	learn: 1.1145918	total: 175ms	remaining: 1.22s
# 5:	learn: 1.0570831	total: 201ms	remaining: 1.14s
# 6:	learn: 1.0113117	total: 227ms	remaining: 1.07s
# 7:	learn: 0.9751721	total: 253ms	remaining: 1.01s
# 8:	learn: 0.9382886	total: 279ms	remaining: 963ms
# 9:	learn: 0.9068075	total: 312ms	remaining: 937ms
# 10:	learn: 0.8765597	total: 339ms	remaining: 895ms
# 11:	learn: 0.8495211	total: 366ms	remaining: 854ms
# 12:	learn: 0.8256697	total: 395ms	remaining: 820ms
# 13:	learn: 0.8032964	total: 421ms	remaining: 781ms
# 14:	learn: 0.7821203	total: 446ms	remaining: 744ms
# 15:	learn: 0.7627245	total: 475ms	remaining: 713ms
# 16:	learn: 0.7468762	total: 502ms	remaining: 679ms
# 17:	learn: 0.7318565	total: 539ms	remaining: 659ms
# 18:	learn: 0.7203231	total: 566ms	remaining: 625ms
# 19:	learn: 0.7092797	total: 592ms	remaining: 592ms
# 20:	learn: 0.6996537	total: 618ms	remaining: 559ms
# 21:	learn: 0.6874059	total: 646ms	remaining: 528ms
# 22:	learn: 0.6761085	total: 675ms	remaining: 499ms
# 23:	learn: 0.6655057	total: 704ms	remaining: 469ms
# 24:	learn: 0.6570162	total: 730ms	remaining: 438ms
# 25:	learn: 0.6477435	total: 766ms	remaining: 412ms
# 26:	learn: 0.6379056	total: 792ms	remaining: 381ms
# 27:	learn: 0.6309197	total: 819ms	remaining: 351ms
# 28:	learn: 0.6232448	total: 845ms	remaining: 321ms
# 29:	learn: 0.6147077	total: 873ms	remaining: 291ms
# 30:	learn: 0.6081269	total: 900ms	remaining: 261ms
# 31:	learn: 0.6031568	total: 930ms	remaining: 232ms
# 32:	learn: 0.5964769	total: 959ms	remaining: 203ms
# 33:	learn: 0.5903327	total: 993ms	remaining: 175ms
# 34:	learn: 0.5855130	total: 1.02s	remaining: 146ms
# 35:	learn: 0.5789845	total: 1.06s	remaining: 118ms
# 36:	learn: 0.5741751	total: 1.09s	remaining: 88.2ms
# 37:	learn: 0.5681979	total: 1.11s	remaining: 58.7ms
# 38:	learn: 0.5632882	total: 1.14s	remaining: 29.3ms
# 39:	learn: 0.5597485	total: 1.17s	remaining: 0us
# 0:	learn: 1.4629400	total: 38.1ms	remaining: 1.49s
# 1:	learn: 1.3326052	total: 65.3ms	remaining: 1.24s
# 2:	learn: 1.2420550	total: 91.8ms	remaining: 1.13s
# 3:	learn: 1.1648414	total: 118ms	remaining: 1.06s
# 4:	learn: 1.1040237	total: 144ms	remaining: 1.01s
# 5:	learn: 1.0488582	total: 174ms	remaining: 983ms
# 6:	learn: 1.0136094	total: 176ms	remaining: 831ms
# 7:	learn: 0.9715444	total: 205ms	remaining: 819ms
# 8:	learn: 0.9321281	total: 233ms	remaining: 802ms
# 9:	learn: 0.8960742	total: 270ms	remaining: 809ms
# 10:	learn: 0.8725581	total: 296ms	remaining: 780ms
# 11:	learn: 0.8474859	total: 325ms	remaining: 759ms
# 12:	learn: 0.8226500	total: 352ms	remaining: 730ms
# 13:	learn: 0.8026067	total: 380ms	remaining: 705ms
# 14:	learn: 0.7844554	total: 406ms	remaining: 676ms
# 15:	learn: 0.7646030	total: 431ms	remaining: 647ms
# 16:	learn: 0.7517800	total: 459ms	remaining: 621ms
# 17:	learn: 0.7365784	total: 494ms	remaining: 604ms
# 18:	learn: 0.7235716	total: 521ms	remaining: 576ms
# 19:	learn: 0.7072334	total: 546ms	remaining: 546ms
# 20:	learn: 0.6990066	total: 572ms	remaining: 518ms
# 21:	learn: 0.6880641	total: 599ms	remaining: 490ms
# 22:	learn: 0.6771390	total: 626ms	remaining: 463ms
# 23:	learn: 0.6679460	total: 653ms	remaining: 435ms
# 24:	learn: 0.6600950	total: 683ms	remaining: 410ms
# 25:	learn: 0.6552189	total: 691ms	remaining: 372ms
# 26:	learn: 0.6476886	total: 727ms	remaining: 350ms
# 27:	learn: 0.6398618	total: 755ms	remaining: 323ms
# 28:	learn: 0.6326457	total: 780ms	remaining: 296ms
# 29:	learn: 0.6254603	total: 807ms	remaining: 269ms
# 30:	learn: 0.6161183	total: 845ms	remaining: 245ms
# 31:	learn: 0.6083289	total: 873ms	remaining: 218ms
# 32:	learn: 0.5998832	total: 900ms	remaining: 191ms
# 33:	learn: 0.5941276	total: 929ms	remaining: 164ms
# 34:	learn: 0.5897500	total: 962ms	remaining: 137ms
# 35:	learn: 0.5851127	total: 988ms	remaining: 110ms
# 36:	learn: 0.5789794	total: 1.01s	remaining: 82.3ms
# 37:	learn: 0.5735211	total: 1.04s	remaining: 54.8ms
# 38:	learn: 0.5678492	total: 1.07s	remaining: 27.4ms
# 39:	learn: 0.5625608	total: 1.1s	remaining: 0us
# 0:	learn: 1.4502918	total: 38.6ms	remaining: 1.51s
# 1:	learn: 1.3312673	total: 65.1ms	remaining: 1.24s
# 2:	learn: 1.2455542	total: 91.8ms	remaining: 1.13s
# 3:	learn: 1.1740394	total: 118ms	remaining: 1.06s
# 4:	learn: 1.1097423	total: 146ms	remaining: 1.02s
# 5:	learn: 1.0569075	total: 173ms	remaining: 981ms
# 6:	learn: 1.0217224	total: 176ms	remaining: 829ms
# 7:	learn: 0.9792306	total: 203ms	remaining: 811ms
# 8:	learn: 0.9389170	total: 230ms	remaining: 792ms
# 9:	learn: 0.9070253	total: 265ms	remaining: 794ms
# 10:	learn: 0.8800652	total: 291ms	remaining: 767ms
# 11:	learn: 0.8526124	total: 319ms	remaining: 745ms
# 12:	learn: 0.8293253	total: 345ms	remaining: 717ms
# 13:	learn: 0.8121369	total: 372ms	remaining: 691ms
# 14:	learn: 0.7953003	total: 400ms	remaining: 667ms
# 15:	learn: 0.7750677	total: 426ms	remaining: 639ms
# 16:	learn: 0.7595554	total: 452ms	remaining: 612ms
# 17:	learn: 0.7434608	total: 490ms	remaining: 599ms
# 18:	learn: 0.7306829	total: 517ms	remaining: 571ms
# 19:	learn: 0.7178348	total: 545ms	remaining: 545ms
# 20:	learn: 0.7082704	total: 573ms	remaining: 518ms
# 21:	learn: 0.7012093	total: 598ms	remaining: 489ms
# 22:	learn: 0.6904382	total: 624ms	remaining: 461ms
# 23:	learn: 0.6799518	total: 650ms	remaining: 434ms
# 24:	learn: 0.6684286	total: 677ms	remaining: 406ms
# 25:	learn: 0.6606309	total: 722ms	remaining: 389ms
# 26:	learn: 0.6517975	total: 755ms	remaining: 363ms
# 27:	learn: 0.6449425	total: 782ms	remaining: 335ms
# 28:	learn: 0.6372276	total: 809ms	remaining: 307ms
# 29:	learn: 0.6303585	total: 835ms	remaining: 278ms
# 30:	learn: 0.6244374	total: 861ms	remaining: 250ms
# 31:	learn: 0.6151840	total: 888ms	remaining: 222ms
# 32:	learn: 0.6095603	total: 915ms	remaining: 194ms
# 33:	learn: 0.6036453	total: 952ms	remaining: 168ms
# 34:	learn: 0.5983656	total: 980ms	remaining: 140ms
# 35:	learn: 0.5916497	total: 1.01s	remaining: 112ms
# 36:	learn: 0.5874107	total: 1.03s	remaining: 84ms
# 37:	learn: 0.5820731	total: 1.06s	remaining: 56.1ms
# 38:	learn: 0.5778636	total: 1.09s	remaining: 28ms
# 39:	learn: 0.5730369	total: 1.12s	remaining: 0us
# 0:	learn: 1.4589894	total: 41.5ms	remaining: 1.62s
# 1:	learn: 1.3354998	total: 68.1ms	remaining: 1.29s
# 2:	learn: 1.2328212	total: 96.7ms	remaining: 1.19s
# 3:	learn: 1.1517063	total: 127ms	remaining: 1.14s
# 4:	learn: 1.0875465	total: 154ms	remaining: 1.08s
# 5:	learn: 1.0341911	total: 181ms	remaining: 1.03s
# 6:	learn: 0.9906258	total: 208ms	remaining: 981ms
# 7:	learn: 0.9522913	total: 236ms	remaining: 943ms
# 8:	learn: 0.9187128	total: 274ms	remaining: 944ms
# 9:	learn: 0.8862104	total: 301ms	remaining: 904ms
# 10:	learn: 0.8569765	total: 336ms	remaining: 885ms
# 11:	learn: 0.8308657	total: 363ms	remaining: 847ms
# 12:	learn: 0.8100861	total: 392ms	remaining: 814ms
# 13:	learn: 0.7909402	total: 419ms	remaining: 779ms
# 14:	learn: 0.7700563	total: 450ms	remaining: 750ms
# 15:	learn: 0.7545477	total: 484ms	remaining: 726ms
# 16:	learn: 0.7389414	total: 511ms	remaining: 692ms
# 17:	learn: 0.7242454	total: 538ms	remaining: 658ms
# 18:	learn: 0.7106325	total: 572ms	remaining: 632ms
# 19:	learn: 0.6979928	total: 605ms	remaining: 605ms
# 20:	learn: 0.6854606	total: 633ms	remaining: 572ms
# 21:	learn: 0.6740769	total: 659ms	remaining: 539ms
# 22:	learn: 0.6638886	total: 696ms	remaining: 514ms
# 23:	learn: 0.6537453	total: 728ms	remaining: 485ms
# 24:	learn: 0.6448019	total: 756ms	remaining: 453ms
# 25:	learn: 0.6352661	total: 783ms	remaining: 422ms
# 26:	learn: 0.6267678	total: 811ms	remaining: 390ms
# 27:	learn: 0.6205430	total: 841ms	remaining: 360ms
# 28:	learn: 0.6141588	total: 867ms	remaining: 329ms
# 29:	learn: 0.6087039	total: 897ms	remaining: 299ms
# 30:	learn: 0.6040295	total: 932ms	remaining: 271ms
# 31:	learn: 0.5992522	total: 964ms	remaining: 241ms
# 32:	learn: 0.5943606	total: 994ms	remaining: 211ms
# 33:	learn: 0.5888697	total: 1.02s	remaining: 180ms
# 34:	learn: 0.5840810	total: 1.05s	remaining: 150ms
# 35:	learn: 0.5788640	total: 1.07s	remaining: 120ms
# 36:	learn: 0.5728358	total: 1.11s	remaining: 90.1ms
# 37:	learn: 0.5670620	total: 1.14s	remaining: 60.1ms
# 38:	learn: 0.5622737	total: 1.17s	remaining: 30ms
# 39:	learn: 0.5573893	total: 1.2s	remaining: 0us
# 0:	learn: 1.4446241	total: 39.4ms	remaining: 1.53s
# 1:	learn: 1.3198900	total: 66.5ms	remaining: 1.26s
# 2:	learn: 1.2319687	total: 107ms	remaining: 1.32s
# 3:	learn: 1.1626986	total: 134ms	remaining: 1.21s
# 4:	learn: 1.0981398	total: 163ms	remaining: 1.14s
# 5:	learn: 1.0393922	total: 190ms	remaining: 1.07s
# 6:	learn: 1.0045212	total: 193ms	remaining: 908ms
# 7:	learn: 0.9632012	total: 220ms	remaining: 879ms
# 8:	learn: 0.9232510	total: 247ms	remaining: 850ms
# 9:	learn: 0.8935997	total: 275ms	remaining: 824ms
# 10:	learn: 0.8645654	total: 301ms	remaining: 795ms
# 11:	learn: 0.8394931	total: 341ms	remaining: 796ms
# 12:	learn: 0.8176894	total: 377ms	remaining: 783ms
# 13:	learn: 0.7940663	total: 405ms	remaining: 753ms
# 14:	learn: 0.7739550	total: 434ms	remaining: 723ms
# 15:	learn: 0.7555985	total: 461ms	remaining: 691ms
# 16:	learn: 0.7397219	total: 487ms	remaining: 659ms
# 17:	learn: 0.7263668	total: 515ms	remaining: 629ms
# 18:	learn: 0.7128647	total: 545ms	remaining: 603ms
# 19:	learn: 0.7007181	total: 578ms	remaining: 578ms
# 20:	learn: 0.6877009	total: 608ms	remaining: 551ms
# 21:	learn: 0.6780750	total: 642ms	remaining: 525ms
# 22:	learn: 0.6713368	total: 669ms	remaining: 494ms
# 23:	learn: 0.6623154	total: 695ms	remaining: 463ms
# 24:	learn: 0.6542609	total: 724ms	remaining: 434ms
# 25:	learn: 0.6506600	total: 731ms	remaining: 394ms
# 26:	learn: 0.6399345	total: 769ms	remaining: 370ms
# 27:	learn: 0.6320594	total: 797ms	remaining: 341ms
# 28:	learn: 0.6247559	total: 825ms	remaining: 313ms
# 29:	learn: 0.6196975	total: 852ms	remaining: 284ms
# 30:	learn: 0.6123266	total: 879ms	remaining: 255ms
# 31:	learn: 0.6057450	total: 905ms	remaining: 226ms
# 32:	learn: 0.5986586	total: 933ms	remaining: 198ms
# 33:	learn: 0.5930810	total: 959ms	remaining: 169ms
# 34:	learn: 0.5861604	total: 997ms	remaining: 142ms
# 35:	learn: 0.5812972	total: 1.02s	remaining: 114ms
# 36:	learn: 0.5764972	total: 1.05s	remaining: 85.3ms
# 37:	learn: 0.5709381	total: 1.08s	remaining: 56.9ms
# 38:	learn: 0.5665301	total: 1.11s	remaining: 28.4ms
# 39:	learn: 0.5610596	total: 1.14s	remaining: 0us
# 0:	learn: 1.4512935	total: 30.9ms	remaining: 1.21s
# ...
# [LightGBM] [Info] Start training from score -3.321566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000127 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2225
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 9
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000109 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2225
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 9
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000103 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2201
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 9
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000175 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2374
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.140066
# [LightGBM] [Info] Start training from score -2.222954
# [LightGBM] [Info] Start training from score -0.361653
# [LightGBM] [Info] Start training from score -3.321566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000114 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2454
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.151667
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.222954
# [LightGBM] [Info] Start training from score -0.361653
# [LightGBM] [Info] Start training from score -3.321566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2456
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000130 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2372
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000110 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2451
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000117 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2374
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.140066
# [LightGBM] [Info] Start training from score -2.222954
# [LightGBM] [Info] Start training from score -0.361653
# [LightGBM] [Info] Start training from score -3.321566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000167 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2454
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.151667
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.222954
# [LightGBM] [Info] Start training from score -0.361653
# [LightGBM] [Info] Start training from score -3.321566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000116 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2456
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2372
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000120 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2451
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000112 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2374
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.140066
# [LightGBM] [Info] Start training from score -2.222954
# [LightGBM] [Info] Start training from score -0.361653
# [LightGBM] [Info] Start training from score -3.321566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000128 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2454
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.151667
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.222954
# [LightGBM] [Info] Start training from score -0.361653
# [LightGBM] [Info] Start training from score -3.321566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000184 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2456
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000118 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2372
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000112 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2451
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2374
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.140066
# [LightGBM] [Info] Start training from score -2.222954
# [LightGBM] [Info] Start training from score -0.361653
# [LightGBM] [Info] Start training from score -3.321566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000154 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2454
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.151667
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.222954
# [LightGBM] [Info] Start training from score -0.361653
# [LightGBM] [Info] Start training from score -3.321566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2456
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000147 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2372
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000128 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2451
# [LightGBM] [Info] Number of data points in the train set: 748, number of used features: 10
# [LightGBM] [Info] Start training from score -3.183416
# [LightGBM] [Info] Start training from score -2.151495
# [LightGBM] [Info] Start training from score -2.210684
# [LightGBM] [Info] Start training from score -0.359735
# [LightGBM] [Info] Start training from score -3.359306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2292
# [LightGBM] [Info] Number of data points in the train set: 935, number of used features: 9
# [LightGBM] [Info] Start training from score -3.176985
# [LightGBM] [Info] Start training from score -2.149199
# [LightGBM] [Info] Start training from score -2.215574
# [LightGBM] [Info] Start training from score -0.360502
# [LightGBM] [Info] Start training from score -3.344039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
# Print the best parameters and score for each model
print("Best parameters for", MinMaxScaler())
print("Random Forest - Train Score:", grid_search_rf.best_score_ * 100, "%")
print("GBM - Train Score:", grid_search_gbm.best_score_ * 100, "%")
print("LightGBM - Train Score:", grid_search_lgbm.best_score_ * 100, "%")
print("XGBoost - Train Score:", grid_search_xgb.best_score_ * 100, "%")
print("CatBoost - Train Score:", grid_search_catboost.best_score_ * 100, "%")
print("Ensemble (VotingClassifier) - Train Score:", grid_search_ensemble.best_score_ * 100, "%")
print("-" * 200)
print("\nCorresponding Test scores")
print("Random Forest - Test Score:", grid_search_rf.best_estimator_.score(test_features, test_labels) * 100, "%")
print("GBM - Test Score:", grid_search_gbm.best_estimator_.score(test_features, test_labels) * 100, "%")
print("LightGBM - Test Score:", grid_search_lgbm.best_estimator_.score(test_features, test_labels) * 100, "%")
print("XGBoost - Test Score:", grid_search_xgb.best_estimator_.score(test_features, encoder.transform(test_labels)) * 100, "%")
print("CatBoost - Test Score:", grid_search_catboost.best_estimator_.score(test_features, test_labels) * 100, "%")
print("Ensemble (VotingClassifier) - Test Score:", grid_search_ensemble.best_estimator_.score(test_features, test_labels) * 100, "%")
# Out:
# Best parameters for MinMaxScaler()
# Random Forest - Train Score: 76.89839572192513 %
# GBM - Train Score: 76.14973262032085 %
# LightGBM - Train Score: 77.2192513368984 %
# XGBoost - Train Score: 76.68449197860963 %
# CatBoost - Train Score: 76.04278074866309 %
# Ensemble (VotingClassifier) - Train Score: 74.75935828877004 %
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Corresponding Test scores
# Random Forest - Test Score: 73.81546134663341 %
# GBM - Test Score: 73.31670822942642 %
# LightGBM - Test Score: 76.05985037406484 %
# XGBoost - Test Score: 75.31172069825436 %
# CatBoost - Test Score: 77.80548628428927 %
# Ensemble (VotingClassifier) - Test Score: 73.31670822942642 %

# %%
task3_bestpipeline_catboost = grid_search_catboost.best_estimator_
task3_bestpipeline_catboost
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('SelectPercentile', SelectPercentile(percentile=35)),
#                 ('CatBoost',
#                  <catboost.core.CatBoostClassifier object at 0x7fe034f03a30>)])

# %%
task3_bestpipeline_catboost.named_steps['CatBoost'].get_params()
# Out:
# {'iterations': 15, 'learning_rate': 0.5, 'min_child_samples': 5}

# %%
print("Total features selected by SelectPercentile function in best params:" , sum(task3_bestpipeline_catboost.named_steps['SelectPercentile'].get_support()))
print("Feature Names chosen: ", train_features.columns[task3_bestpipeline_catboost.named_steps['SelectPercentile'].get_support()])
# Out:
# Total features selected by SelectPercentile function in best params: 25
# Feature Names chosen:  Index(['clauses_vars_ratio', 'vcg_var_max', 'vcg_var_entropy',
#        'vcg_clause_coeff', 'vcg_clause_min', 'vcg_clause_max', 'vg_mean',
#        'vg_min', 'vg_max', 'pnc_ratio_mean', 'pnc_ratio_coeff',
#        'pnc_ratio_entropy', 'pnv_ratio_coeff', 'pnv_ratio_max',
#        'pnv_ratio_entropy', 'pnv_ratio_stdev', 'binary_ratio', 'ternary_ratio',
#        'ternary+', 'hc_fraction', 'hc_var_max', 'hc_var_entropy',
#        'unit_props_at_depth_4', 'unit_props_at_depth_64',
#        'saps_BestSolution_CoeffVariance'],
#       dtype='object')

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

preds = task3_bestpipeline_catboost.predict(test_features)
report = classification_report(test_labels,preds)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        addmc       0.87      0.81      0.84        16
#           d4       0.75      0.31      0.43        59
#        ganak       0.54      0.66      0.60        38
#         gpmc       0.81      0.94      0.87       269
#     sharpsat       0.67      0.11      0.18        19
#
#     accuracy                           0.78       401
#    macro avg       0.73      0.56      0.58       401
# weighted avg       0.77      0.78      0.75       401

# %%
preds = task3_bestpipeline_catboost.predict(test_features)
matrix = confusion_matrix(test_labels,preds)
print(matrix)
# Out:
# [[ 13   0   0   3   0]
#  [  0  18   6  35   0]
#  [  0   0  25  12   1]
#  [  2   4   9 254   0]
#  [  0   2   6   9   2]]

# %%
from joblib import dump, load
dump(task3_bestpipeline_catboost, 'final_catboost_pipeline.joblib')
# Out:
# ['final_catboost_pipeline.joblib']

# %% [markdown]
# # Task 3 - Explanation
#
# #### 1) Building on Task 2, only the model was switched in the pipeline from KNN to various other Machine Learning models like RandomForestClassifier, GradientBoostingClassifier (GBM), LightGBM, XGBoost, CatBoost and VotingClassifier (combination of RandomForestClassifier, GBM, LightGBM).
# #### 2) Experimentation was performed on separate pipelines to visualise the difference in model fits and choose the best one. MinMaxScaling and SelectPercentile were common components across all the pipelines.
# #### 3) Although highest training accuracy (77.2%) was achieved by LightGBM Classifier on it's best set of parameters found out by hyperparameter tuning on GridSearchCV, highest validation accuracy  of 77.8% was achieved by CatBoost Classifier on it's own best set of parameters with a very marginal difference between the train accuracy between the two models. Catboost train accuracy - 76.04%
# #### 4) Therefore, Final model chosen was the Catboost Classifier which has been uploaded to GitHub. Details of the model - SelectPercentile chose 25 features with top 35%ile scores, Catboost classifier with {'iterations': 15, 'learning_rate': 0.5, 'min_child_samples': 5} as tuned parameters.

# %% [markdown]
# # <font color="blue">Testing part</font>
#
# Save your best model into your GitHub. And create a single code cell that loads it and evaluates it on the test dataset.

# %%
from joblib import dump, load
from io import BytesIO
import requests
import pandas as pd

# INSERT YOUR MODEL'S URL
mLink = 'https://github.com/Abhi21298/DataMining-Assignment2/blob/main/final_catboost_pipeline.joblib?raw=true'
mfile = BytesIO(requests.get(mLink).content)
model = load(mfile)

df = pd.read_csv("test_data.csv")

X_test = df.drop(['label'], axis = 1)

Y_test = df['label']
# Your code here
print("Final Accuracy - ", model.score(X_test, Y_test) * 100, "%")
# Out:
# C:\Users\abhir\miniconda3\lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.2.2 when using version 1.4.1.post1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\abhir\miniconda3\lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator SelectPercentile from version 1.2.2 when using version 1.4.1.post1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# C:\Users\abhir\miniconda3\lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.2.2 when using version 1.4.1.post1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Final Accuracy -  74.32835820895522 %
